# %% [markdown]
# ## Understanding Retrieval-Augmented Generation (RAG) & Use of VectorStore
# *by Ong Chin Ann*
#
# #### Objectives
# - To understand the concept of Retrival Augmented Generation (RAG)
# - To understand the usage of text-embedding model for vectorization
# - To familarized with LangChain RAG-related components (Document Loader, Text Splitter, retrievers etc...)
# - To develop a custom chatbot with RAG approach
#
#
# If you find understanding RAG difficult, maybe you can look through the following resource after you have completed the exercise/walkthrough. <br/>
# Link: https://www.datacamp.com/blog/what-is-retrieval-augmented-generation-rag
#
#
# #### RAG Processes
# * Step 1: Loading and Chunking Data
# * Step 2: Construct Vector Store / Database
# * Step 3: Perform Similarity Search based on user Query
# * Step 4: Generate response from LLM based on document retrieved from the Vector Database and user query
#
#
# ##### Required Dependencies
# - pip install pypdf
# - pip install docx2txt

# %% [markdown]
# ##### Loading required libraries
#
# Link:
# - PDF Loader: https://python.langchain.com/v0.1/docs/modules/data_connection/document_loaders/pdf/
# - DOCX Loader: https://python.langchain.com/v0.1/docs/integrations/document_loaders/microsoft_word/
# - FAISS: https://python.langchain.com/v0.1/docs/integrations/vectorstores/faiss/
# - AzureOpenAIEmbeddings: https://python.langchain.com/v0.1/docs/integrations/text_embedding/azureopenai/

# %%
import os
from dotenv import load_dotenv
from langchain_community.document_loaders import TextLoader, Docx2txtLoader, PyPDFLoader
load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# #### Step 1a: Document Loader
# The following code shows how to load document (docx & pdf) using Docx2txtLoader & PyPDFLoader classes from LangChain
#
# Link:
# - PDF Loader: https://python.langchain.com/v0.1/docs/modules/data_connection/document_loaders/pdf/
# - DOCX Loader: https://python.langchain.com/v0.1/docs/integrations/document_loaders/microsoft_word/

# %%
## Loading PDF Documents
info_loader = PyPDFLoader("resources/CC0003-Outline-AY2021-S28631bdc2-fab3-4039-a923-723ef29f6e8e.pdf")
course_info = info_loader.load()
print("Num Docs", len(course_info))
course_info
# Out:
# Num Docs 1
# [Document(page_content='                                            \n \n \nCC000 3 Ethics and Civics in a Multicultural World  \n        \nAcademic Year  AY202 2/23 \nAcademic Units  2AUs  \nTutorial Hours  26 \n \nCOURSE AIMS  \nThis course aims to equip students with the necessary philosophical foundations to understand theories of ethics \nand subsequently apply those theories to real -life scenarios and issues. It also aims to enable students to understand \nand critically assess th e civic institutions that structure their local and global communities. To these ends, the course \nwill examine the nature of ethics, its understanding across different cultures, and how it is manifested in concepts, \nsocial structures, and governance instit utions.  \n \nTopics to be explored include human rights, democracy, freedom of speech  and inequality. The rights and duties of \ncitizenship shall be a unifying theme. Students will think through assumptions they hold on all of these matters. \nThey will be provided with the tools to understand various and even contradictory perspectives on these important \nissues. There will be a substantial amount of time devoted toward understanding Singapore’s own institutions and \nideologies, which are of course products specific to the country’s own unique historical and geo -political \ncircumstances. We expect t hat students will have a better appreciation of the country’s institutions after reading \nthe module.  \n \nINTENDED LEARNING OUTCOMES  \nBy the end of this course, you should be able to:  \n1. Identify the morally relevant features of situations, decisions, and policies;  \n2. Explain your moral responsibilities to actively participate in activities that strengthen your local and global \ncommunities;  \n3. Critically assess th e civic structures and institutions of your communities and your role in them;  \n4. Make well -informed arguments on some major contemporary issues.  \n5. Apply ethics and civics concepts to the Singapore context.  \n \nCOURSE CONTENT  \n1. Introduction – What is Ethics, Civics, Multiculturalism and how is this relevant to you?  \n2. Reasoning for ethics and civics + Logic Quiz  \n3. Human Rights Part 1: Human Trafficking  \n4. Human Rights Part 2: Disability  \n5. Reproduction Ethics : Abortion  \n6. Ethics of Death and Dying : Euthanasia and Assisted Suicide  \n7. Equality & Meritocracy  \n8. Multicultralism  \n9. Political Systems: Types, Features, and Moral Justifications  \n10. Free Speech: Meanings, Limitations, and Implications  \n \nREFERENCES  \n1. Russ Shafer -Landau, “What is Morality?” pp. 1 -6 from Living Ethics  (US: Oxford University Press, 2019).  \n2. Al-Farabi, excerpts from “The Attainment of Happiness” pp. 113 -119 from Introduction to World Philosophy  \n(US: Oxford University Press, 2009).  \n3. Teo You Yenn, This is What Inequality Looks Like , pp. 41 -90 (Singapore: Ethos Books, 2018).  \n ', metadata={'source': 'resources/CC0003-Outline-AY2021-S28631bdc2-fab3-4039-a923-723ef29f6e8e.pdf', 'page': 0})]

# %%
## Loading PDF Documents
content_loader = PyPDFLoader("resources/cc3.pdf")
course_content = content_loader.load()
print("Num Docs", len(course_content))
course_content
# Out:
# Num Docs 53
# [Document(page_content='Lecture 1:Why do ethics and civics matter to everyone/ what is the purposeof studying this course?-Learn how to engage in a reasoned discussion about issues in ethics and civics(which is what we should do in a multicultural world)-Learn to critically examine the various reasons that all of us may have, given ourdifferences, to believe or act with regard to ethical issues-Different people have different ideas and conceptions as to how they should livewhether as individuals or as citizens-We belong in overlapping societies (e.g. Singapore society, Internet society, schoolsocieties)-Reflecting on the kinds of actions that either would or would not contribute to how wethink we should live, both as an individual and as a citizen, we find that this includesa wide range of concerns-Provide some direction on how we can better come up with and/ or evaluate ourreasons in all these situations and more (these situations do matter to us or others)Convincing others why we should be allowed to live our lives the waywe want:-Give reasons to explain/ justify why we think what we think-Sometimes these reasons are good or badCourse Expectations:-Identify the morally relevant features of situations, decisions and policies-Explain your moral responsibilities to actively participate in activities that strengthenyour local and global communities-Critically assess the civic structures and institutions of your communities and yourrole in them-Make well-informed arguments on some major contemporary issues-Apply ethics and civics concepts to the Singapore context-Remain open to reasons for how others might be negatively affected or how youyourself might be negatively affected → through this, we can find out why thingsmatter to us or why things matter to others\n2', metadata={'source': 'resources/cc3.pdf', 'page': 0}),
#  Document(page_content='Standard of conduct:-Be respectful to others-Be sensitive of what you say and how you say it-Include appropriate content in discussions==Ethics is the study of morality(how one should live)At least 2 different approaches to ethics:-Theory-led (Normative ethics)-Circumstances-led (Applied ethics)Theory-led approach-Ethical theory involves a set of principles that are meant to apply universally toanyone and what they should do in general-Eg. Utilitarianism (act in a way that maximises overall pleasure)-Cannot mix ethical theories or different parts ethical theories together-Pick what is most reasonable and makes the most sense-Make sure that the ethical theory you commit to is themost justifiedand has themost explanatory powerCircumstances-led approach-Looks at the 5W1H of a given ethical scenario to provide reasons for whethersomeone should act a certain wayTerminology:-Ethics: Thestudyof how one should live (the studyof morality)●Ethics look into which act someone should perform, the reasons behind whythe person perform such an act, and if these reasons are good or bad-Ethical theory: Involves a set of principles that are meant to apply universally toanyone and what they should do in general.●Encountering a particular ethical issue = apply the theory to see what weshould do-Morality: How one should live-Civics: The study of how one should live as a citizen●Civics = our rights and duties to the state and to each other as citizens of astate in relation to which we draw benefits and protection●The study of how one should live as a citizen then, does not only concernvoting and taxes, nor does it only concern open-air demonstrations andrallies. It also concerns our everyday lives and how the rights and duties ofcitizens might be found in the structures we encounter on a daily basis.\n3', metadata={'source': 'resources/cc3.pdf', 'page': 1}),
#  Document(page_content='-Democracy: People of the state are the ones with the ultimate power●Democratic society = collective project to be carried out by all its citizens,while also taking into account others who might be affected by this project-Monarchy: Monarch (king or queen) has ultimate power-Regression analysis: aim to establish a conditional relation between independent anddependent variables-Moral philosophy:●Main definition: the practice of reflecting philosophically on morality●Practical subject with many significant and important theoretical elements●Help you develop your own moral outlook of life (i.e. help you come to asharper sense of what does and does not matter from a moral point of view)●Form a view of what considerations do, and do not, need to be takenseriously●How we should develop our reasoning, attention and emotions●Help you think through nature of your relationships with other people, andwith other things of value (e.g. animal world, natural environment)●Help you think about how you should use your talents and energy●Help you decide what your goals in life should be●Looks into how you should try to influence and/ or educate those around youConcepts:Both ethics and civics:-Ethics and civics = exchange of reasons (care about quality of reasons, not quantity)-Ethics and civics = currency of any discussion-Ethics and civics are multicultural → we are constantly engaging in an exchange ofreasons with others who are culturally dissimilar or different from us - and weconstantly have to adapt our beliefs and actions as a result of such an exchange-As we change, the various cultures that each of us make up change and multiply-Ethics and civics look into the level of reasons, not the level of beliefs and opinions-Doing ethics and civics doesNOTmean:●Merely sharing opinions or beliefs without rational support●Finding a fancy word or phrase for something●Finding an -ism that sounds cool/ resonates with you (you should considerdifferent theories, even though you may not agree with them)\n4', metadata={'source': 'resources/cc3.pdf', 'page': 2}),
#  Document(page_content='●Studying ethics and civics at university level is primarily aboutpithy(expressive) sayings or which-person-said-what → relying on quotesstops you from reasoning independently-What doing ethics and civics actually mean:●No one cares about your belief or opinion, but they care about whether youshould have that belief●Care about opinions and beliefs that have undergone a process of anexchange of reasons with others (i.e. what matters is reasonable belief)-Questions to ask yourself when doing ethics and civics:●Why should others take seriously why you believe it is the best way to live orthe best way to organise and participate in a state?●What sort of reasons can you offer others that they should care about howyou think you should live your life or how society should be run?-Always engaged in ethics and civicsEthics:-Normative ethics: Theory-led approach●Ethical theory: Involves a set of principles that are meant to be applieduniversally to anyone and what they should do in general.●Apply ethical theories to ethical issues or ethical scenarios●Pick ethical theories that make the most sense and is the most reasonable ofour individual and collective lived experiences of the world●Make sure that the ethical theory you choose is the most justified and has themost explanatory power-Applied ethics: Circumstances-led approach●Looks into the who, what, when, where, why of a situation●Who: Who are the actors of a given scenario, and who are the ones receivingthe act → asking this helps us consider the context/ background of the actorsand receivers●What: Is the evidence that you’re looking atmorallyrelevant?●When: Time of action●Where: Place where action happened●Why: Look into causes and conditions of scenario●Theory-led approach and circumstances-led approach should work together-Studying ethics allows you to communicate with others about ethical issues-As students, we must pay attention to the details of everyday scenarios and becomesensitised to what might be ethical circumstances as we go about our lives\n5', metadata={'source': 'resources/cc3.pdf', 'page': 3}),
#  Document(page_content='Civics:-Studying civics allows you to communicate with others about civic issues-Looks into what sort of state is in question, and how citizens relate to it and to eachother-State:●Unique, historical, stable site●Have economic, political and social relations●Characteristics of a state and citizens’ corresponding rights and dutiesdepends on state’s history, people, culture, goods, services, forms ofgovernment, values of governmentMoral philosophy:-Has a subject matter, morality, and a method, philosophical reasoning-Ideas in moral philosophy are very important-Ideas should be studied by anyone who wants to think seriously about morality-Should gain understanding of a view in its subtlety and complexity before dismissingit-Globalisation (Western culture are widespread in the world) → should be aware ofthe major traditions of Western moral philosophy to understand world history,literature, culture-Should not just focus on Western theories of morality, but also explore othertraditions of ethicsTheories:-Utilitarianism: Principle of Utility → act in a way that maximises overall pleasure (Theright thing to do is always to ensure that the action that one takes has theconsequence of increasing the total amount of pleasure in the universe)Claims:-Normative claims: what we ought to do, or should do●Morally relevant reasons support normative claims-Descriptive claims: a particular state of affairs (what is happening in the situation e.g.Tom helped Brenda)\n6', metadata={'source': 'resources/cc3.pdf', 'page': 4}),
#  Document(page_content='Lecture 2 -Clarity of ReasonsShould have reasonable belief in ethics. Dispute in ethics and civics is always at the level ofreasons, not at the level of belief or opinionsAsimplistic utilitarianunderstands that what isnecessary and sufficientfor any action tobe morally right is for it to maximise overall pleasure.2.2 Cogency of Reasons-The convincingness of your argument-When providing reasons, the structure of your argument should be explicit. Merely listing anumber of reasons is not an argument.-When our beliefs are rationally supported by our reasons, we have acogent argumentforthem.\n-A pros-and-cons presentation of reasons is NEVER an argument because it does notgive us any sense of the logical relations of the reasons to each other - without anysense of their relative weightage. That is, a pros–and-cons presentation provideszero support for any claim or position. We care NOT ABOUT THE QUANTITY ofreasons but only the QUALITY of reasons.Arguments should:1.Involve true premises2.Have a valid logical structure3.Not committee any informal fallaciesTHree approaches to establish if someone’s reasons are inadequate:1.Verify that the reasons are false2.Find that the reasons relate to each other in an invalid logical structure3.Realise that there’s an informal fallacy\n7', metadata={'source': 'resources/cc3.pdf', 'page': 5}),
#  Document(page_content='Types of criticisms:External: How a certain standard is not metInternal: How claims made/actions performed are contradictory (because something cannotbe both A and not-A at the same time )Criticisms must themselves meet the standards of cogency if they are to beconvincing.Outline for Lecture 2:1)What to Provide for Supporting Reasons2)Why Concepts are important3)Conditions; Sufficiency and Necessity4)Why is it important for Clarity of Reasons5)Cogency of Reasons6)Elements of an Argument7)TWO Types of Reasons8)Internal and External Criticism1)What to Provide for Supporting Reasonsa)Ensure that you help others understand how you rationally arrive at acertain positionb)Provide an argument for your brief with as much or as little contextualinformation as requiredc)Keep in mind that others may be unfamiliar with the content whenpresenting or writingd)Never assume that they should make the argumentative connectionsthemselves or that they can read your mind2)Why Concepts are importantConcepts allow for a common ground for discussion and allows to be moreprecise and accurate in saying somethingConcepts are only important when they serve the purpose of rationalitysupporting your beliefs in an exchange of reasons3)Conditions; Sufficiency and NecessitySufficiencyis when something is enough to be consideredassomething elseWhen (a) is sufficient (enough) to be considered to be (b)E.g. Triangle (a) is sufficient / can be considered to be a shape (b)\n8', metadata={'source': 'resources/cc3.pdf', 'page': 6}),
#  Document(page_content='p is sufficient for qNecessitycan be thought of as conditionsOnly with p, then can be qE.g. For X to be a triangle, X needs to have edges, if not it cannot beconsidered to be a triangleNote there are situations where both can apply:A Triangle is a shape and a Triangle requires edges4)Why is it important for Clarity of ReasonsBy defining the concepts clearly, and by providing the necessary and sufficientconditions, our reasons can be clearly understood by others, only then can wehave any productive discussion in ethics and civics.5)Cogency of ReasonsWhen providing reasons, the structure of your argument should be explicit.Andmerely listing a number of reasons is not an argument.6)Elements of an Argument1)True or False Sentences / StatementsE.g. “An A- grade is a good grade”2)Propositions (Argument form)If a grade mets the following criteria, it is a good grade,1)Only the top 20% of submissions can be an A- grade3)Logical form (formal logic)A- = top 20%4)State of affairs (Basically conclusion)Thus, A- is a good grade7)Internal and External CriticismWhen a concept or argument is problematic: 2 Criticisms\n9', metadata={'source': 'resources/cc3.pdf', 'page': 7}),
#  Document(page_content='External Criticism: How a certain standard(s) is not metInternal Criticism: How the claims made/actions performed arecontradictoryNote that: Criticisms must themselves meet the standard of cogency if theyare to be convincing8)TWO Types of ReasonsIndividual Reason: A reason that makes reference to properties (i.e.attributes) of X as sufficient conditionsStructural Reason: A reason that makes reference to X’s position in astructure as sufficient conditionsE.g. Why does X show up late to class?Individual Reason: could be that X has a walking disabilityStructural Reason: Alot of commuters (element), principle (assumption thateveryone is able-bodied commuters), systematic relation(transport system)9)What is a Structure?A structure has elements that are systematically related to each otheraccording to principles particular to that structureE.g.Argumentis astructurebecause:It has premises and a conclusion -its elementsIt has a set of grammatical sentences -its systematicrelationIt conforms to logical laws -its principles10)Additional ReadingsMeta-ethics:asks questions about the nature and existenceof value and ourknowledge of itNormative-ethics:asks questions about what we shoulddo and how we should live.\n10', metadata={'source': 'resources/cc3.pdf', 'page': 8}),
#  Document(page_content='Applied-ethics:asks questions about specific moral problems, such as whetherabortion or terrorism are sometimes permissible, or whether it was right to use theatomic bomb in the Second World War.Logical argument:-An argument is a logical deduction starting from one or more premises andending with a conclusion-Argument is valid if the conclusion if correctly deduced from the premise\n11', metadata={'source': 'resources/cc3.pdf', 'page': 9}),
#  Document(page_content='Lecture 3: Human rights and TraffickingHuman rights and human traffickingAS DEFINED BY THE UNHuman Rights→ Human rights are rights inherent toall human beings, regardlessof race, sex, nationality, ethnicity, language, religion, or any other status. Humanrights include the right to life and liberty, freedom from slavery and torture, freedomof opinion and expression, the right to work and education, and many more.●Rights we have simply because we exist as human beings (UN HumanRights)●Define and protect fundamental freedoms and entitlements for all humans●Legal, moral and universal1.Legal Rights●Described in the laws of a country’s legal jurisdiction, exists because of alegal statute / some other government action●May change over time (& varies from place to place), subject to the actions ofthe government (has the power to create, interpret and enforce the laws)Eg. Constitutional Rights – Liberty of the Person, Prohibition of Slavery & ForcedLabour, Protection Against Retrospective Criminal Laws, Repeated Trials, EqualProtection, Prohibition of Banishment, Right to Freedom of Movement, Rights toSpeech, Assembly and Association, Freedom of Religion, Right to Worship, Rightsto Education2.Moral Rights-- Part of conventional and criticalmorality. Free from Biases,mistaken belief and irrationality. (Unlike Legal Rights)●Exist outside conventions or legal systems. Universal code of ethics, formedby groups of people based on their moral compass.●May be morally right, but not be legally right. eg. Women’s rights in the MiddleEast, Inability for minority groups to vote.3.Universal Rights-- Respecting inherent dignityof all humans.Equality.Embodied by the UDHR (Universal Declaration of Human Rights)UDHR -- Adopted by the UN in response to atrocities committed in WW2 like theHolocaust*7 Core Human Rights Treaties●International Covenant on Civil and political Rights (ICCPR)●International Covenant on economic, Social and Cultural Rights (ICESCR)●International Convention on the Elimination of All Forms of RacialDiscrimination (CERD)●Convention on the Elimination of All Forms of Discrimination Against Women(CEDW)\n12', metadata={'source': 'resources/cc3.pdf', 'page': 10}),
#  Document(page_content='●Convention against Torture and other Cruel, Inhuman or Degrading Treatmentor Punishment●Convention on the Rights of the Child●International Convention on the Protection of the Rights of all Migrant Workersand members of their Families.Articles of the UDHRArticle 1→ All human beings are bornfree and equalin dignity and rights. They areendowed with reason and conscience and should act towards one another in a spiritof brotherhood.2→ Rights against discrimination3-15,19-21→ Civil and political rights, includingrights to life, liberty, personal securityand political participation16-18,22-27→ Economic,social and cultural rights,including rights to an adequatestandard of living, social security, work, rest and leisure, family, education andparticipation in the cultural life of a community28→ Everyone is entitled to asocial and internationalorderin which the rights andfreedoms set forth in this Declaration can be fully realised29→ Everyone has duties to the community, rights andfreedoms subject only tolimitations as determined by the law, for the purpose of securing the rights andfreedoms of others, and of meeting the just requirements of morality, public orderand general welfare in a democratic society.These treaties are the basis of over 70 other treaties that are permanently appliedaround the world today.AdvantagesDisadvantages- Avoids discrimination- improves quality of life from humans- set standard for individuals to betreated equally- procedure and framework for govt toprotect and promote human rights- not considered international law- cannot be legally enforced -> countriesmay select which to employ -> due todifferences: 1. Cultural context 2.Political context 3. Limited resourcesMoral vs Legal Rights?Moral rights are not always legal rights, and legal rights are not always moral rights.Eg. The right to own slaves (America, SEA etc.)\n13', metadata={'source': 'resources/cc3.pdf', 'page': 11}),
#  Document(page_content='Slavery was a legal right. Supporting slave owners by reporting escapees was also alegal duty. However, these actions aremorally bankruptand involve the exploitationof other human beings.Countries may try to apply legal rights and moral rights together, but are limited bycountries’ political climates, resources and cultural differences. A.k.a. Someminorities are considered less important, thus less effort is given to enforce theirrights.Human TraffickingAccording to the UNTOC,1. Recruited/Transported using2. Force/coercion of those in a vulnerable position or providing/receiving benefits toachieve the consent of control over another person,3. With the end goal of exploitation.“The World’s Oldest Trade”-Debts, punishment, starvation and war captivity, slave raiding and trade-Debt / Bonded labour,  Employed close to their areas of origin; inter-regionalslave trade (kings, courtiers, merchants)Used in:●Agriculture: produce sugar, pepper, cloves, rice & other crops●Manufacturing: as smiths, coopers, tailor, household related●Industry: sugar refineries, distilleries, ship buildingModern-day Slavery-Forms of Human Trafficking: Child abduction, Forced child beggar, Sellingbaby, Human cage, Forced prostitution, Forced labor, Forced marriage, Organtheft, Trafficking boat-Forced labour in Asia-Pacific region is world’s most lucrative (especially inCambodia, Indonesia & Thailand)  due to Armed conflict and Natural disasterse.g. Myanmar, PhilippinesThreats of Human Trafficking:Criminal: Use of Force, Coercion, Fraud, ExploitationNational security: Terrorism, drugs, political/armed conflict; border securityHuman/social aspects: Physical and mental health consequencesHuman rights: Protection, prosecution, legislation, advocacyImpact of COVID-19 on Human Trafficking-Global rise in unemployment & reduction of income  “Made a desperatesituation even worse”\n14', metadata={'source': 'resources/cc3.pdf', 'page': 12}),
#  Document(page_content='-Rise in domestic violence, increased irregular migration, rise in child labour,online grooming and exploitation, rise in domestic sexual & labour trafficking,abuse victims trapped with abusersHUMAN DIGNITY – HUMANITY PRINCIPLE (IMMANUEL KANT)The Principal of Humanity provides a rationale for this equal dignity shared by allhuman beingsAll human beings are rational and autonomous beings  entitled to equal respect●Rational:Using reason to figure out what to do ina morally acceptable way(Shafer-Landau 2020: 120)●Autonomous: To be in control of one’s own life (Shafer-Landau2020: 120)●Kant:Rationality and autonomy of persons makes themsupremely valuableand worthy of respect-To treat a person as an end and to respect them as they deserve, onemust support theirrationality and autonomyrespectis owed to everyperson equally since all persons and rational and autonomous beingsKant:To always treat a person as an end, never merelyas a meansCommitment to impartiality-All persons deserve equal respect due to their rationality and autonomy –regardless of their sex, race, age, etc-Discrimination based on these & other characteristics unrelated to theirrationality and autonomy fails to respect persons as endsTreating Persons as Mere Means:-To use a person in a way that they could not rationally consent to being used-Principle of humanity prohibits treating someone as a mere means-Examples of mere means: Deception, Coercion (e.g. slavery, sexual assault),Exploitation, Violations of privacyHuman Flourishing – Eudaimonia (Aristotle)“Happiness”, “Flourishing” through living virtuously-Reflects “pursuit of virtue, excellence, and the beast within us” (Huta &Waterman, 2014: 1426)-A good life can be attained by practising virtues like courage, wisdom, goodhumour, moderation , kindness etc-Eudaimonia: Highest good that human beings can attain (Intrinsically good)The Golden Rule1.Treat others as you want to be treated (Gensler 2013: 1)2.According to Gensler, the “Golden Rule” has been common to all majorreligions and philosophies throughout human history3.Commitment to human dignity, in the form of the “Golden Rule”, the “Rule ofReciprocity”, or Universal ethics for humans\n15', metadata={'source': 'resources/cc3.pdf', 'page': 13}),
#  Document(page_content='Lecture 4: DisabilityLecture slides●People with disabilities are the world’s largest minoritySocial exclusion●Social inclusion definition○It encompasses, influences, and shapes three main domains of aperson’s life, social, economic and political○Unesco’s definition:■A society for all in which every individual, each with rights andresponsibilities, has an active role to play●Why is social exclusion an issue?○Unequal access to resources, unequal participation, denial ofopportunities●Implications of social exclusion○Corrosion and breakdown of society because of poor social cohesion○Entrench and worsen the marginalised conditions of segments ofsociety○Communities who are socially excluded face unemployment, pooreducational outcomes, low income, poor housing conditions, poorhealth and family breakdown\nUNCRPD●UDHR vs UNCRPD\n16', metadata={'source': 'resources/cc3.pdf', 'page': 14}),
#  Document(page_content='○UDHR: to promote and protect the inherent dignity and equality of allhuman beings○UNCRPD: to promote, protect and to ensure the fulland equalenjoyment of all human rights as well as the fundamental freedoms ofall persons with disabilities, and to promote respect for the inherentdignity●Info on UNCRPD:○Marks shift in the way societies view and treat persons with disabilitiescompared to the past○Emphasises and enshrines the rights of PWDs as right holders andsubjects of law○Puts them in the centre with rights to fully participate in formulating andimplementing policies that affects them○Reflects the social perspective that sees disability as a universalhuman experience not unique○Shifts the lens from seeing them as just unfortunate few, the outliers ofsociety○Eliminates legal and social barriers that prevents PWDs from fullyparticipating in society●UNCRPD’s definition of ‘people with disabilities’:○Article 1 of the CRPD: open -ended description of the treaty’s targetpopulation: Persons with disabilities include those who have long-termphysical, mental, intellectual or sensory impairments which ininteraction with various barriers may hinder their full and effectiveparticipation ins society on an equal basis with others●Measures under UNCRPD:○Accessibility (article 9)○Living independently and being included in the community (article 19)○Personal mobility (article 20)○Habilitation and rehabilitation (article 26)●General principles of UNCRPD:1.Respect for inherent dignity, individual autonomy including the freedomto make one’s own choices, and independence of persons2.Non-discrimination3.Full and effective participation and inclusion in society4.Respect for differences and acceptance of persons with disability aspart of human diversity ad humanity5.Equality of opportunity6.Accessibility7.Equality between men and women8.Respect for the evolving capacities of children with disabilities andrespect for the right of children with disabilities to preserve theiridentities\n17', metadata={'source': 'resources/cc3.pdf', 'page': 15}),
#  Document(page_content='Disability in SG●Those whose prospects of securing, retaining places and advancing ineducation and training institutions, employment and recreation as equalmembers of the community are substantially reduced as a result ofphysical,sensory, intellectual and developmental impairments(such as autismspectrum disorder, down syndrome, cerebral palsy)SG government’s stand and policies towards the disabled (pg 26- 29)●Rationale behind govt’s shift in priorities and policies with regards to disabledpersons:●National interests of developing human resource●Develop ALL segments of the society so that they will be productive andcontributing members of society●Key milestones of disability policies○1980:Car Park Label Scheme:access to wider parkingspaces fordrivers and passengers with mobility impairment○2003:Early Intervention Programme for Infants andChildren (Eipic):provide median and high levels of early intervention support forchildren ages <= 6○2006: introduction offirst wheelchair- friendly publicbus,ENABLE fundlaunched to provide funding to employers who need to redesign jobs/modify workplace/ implement training when hiring people withdisabilities○2019:Compulsory Edu Act extendedto children withspecial needswhere they will have to attend SPED schools●Social inclusion in SG:\n●The way forward:○Third Enabling Master Plan (2017 -2021)■Singapore to be a caring and inclusive society where personswith disabilities are empowered to achieve their fullest potentialand participate fully as integral and contributing members of thesociety■6 in 10 PWDs do not feel socially included, accepted and givenequal opportunities to contribute to the society (NCSS Study)\n18', metadata={'source': 'resources/cc3.pdf', 'page': 16}),
#  Document(page_content="Dignity●Prohibitionof all types of inhuman treatment, humiliation,or degradation byone person over another●Assuranceof the possibility for individual choiceand the conditions for ‘eachindividual’s self-fulfilment’, autonomy, or self-realisation●Recognitionthat the protection of group identityand culture may be essentialfor the protection of personal dignity●Creationof the necessary conditions for each individualto have theiressential needs satisfiedRights and Responsibilities●Shift in approach from one motivated by ‘charity’ to one based on rights andequal opportunities●Protecting and upholding rights of disabled and disadvantaged is a form ofduty and responsibility at individual, societal and state levels●Limitations and disadvantages of disability laws:○Companies in Thailand and Japan pay the fine to governments for nothiring PWDs rather than hire them because they think there is a biggereconomic cost involved○A law might be in place but societal attitudes may not be in sync withthe government legislation●Prevailing issues faced by PWDs:○Lack of physical environment accessible to PWDs○Attitudinal barriers○Employment○Participation in society○Discrimination and stigma○Isolation and social exclusionConclusion●Human rights are fundamental and universal●Policies should focus on heterogeneity of disabled people●Inclusivity: Include the voices, aspirations, rights, what's importantTOthemand what's importantFORthemReadings: Disability rightsSocial inclusion●Social inclusion isdefinedasthe process of improvingthe terms ofparticipation in society for people who are disadvantaged on the basisof age, sex, disability, race, ethnicity, origin,religion, or economic orother status, through enhanced opportunities, access toresources,voice and respect for rights.●Promoting social inclusion\n19", metadata={'source': 'resources/cc3.pdf', 'page': 17}),
#  Document(page_content='○Tackling social exclusion○Removing barriers to people’s participation in society○Taking active inclusionary steps to facilitate such participation●Social inclusion processes○Addressing the drivers of exclusion (includes certain policies andinstitutions +  discriminatory attitudes and behaviours)○Actively “bringing people in”●Policies and institutions○Define the “rules of the game” for social interactions and thedistribution of power, status and control over resources○Drive social exclusion or mitigate its impacts●Norms, policies and institutions can also result in participation in society buton adverse terms (prevent development of social inclusion)Social Impact on the Disabled in Singapore●SG tends to focus on economicprerogatives(a rightor privilege exclusive to aparticular individual or class), and to discouragea rights-based, socio-politicalunderstanding of disability.●Persons with Disabilities (PWDs) are often seen as objects of charity ratherthan as subjects with rights●Catering to the needs of an ageing population has strengthened the case forinclusivity○Advantages of barrier-free environments → to prevent the costimplications of a fall that poses a heightened risk for the elderly.●Impact of international developments on SG○2006 UN Convention on the Rights of PWDs (UNCRPD) haveincreased the pressure on Singapore to better conform to internationalnorms●Employment of PWDs○PWDs inability to access the general employment sphere reinforcestheir societal exclusion○Negativeimpact of social exclusion on PWDs:■trap them in an economically dependent situation■heightens feelings of inferiority and personal worthlessness →end up internalising the belief that they are an undesirablepresence in society○Solution:■Making space for PWDs to contribute economically in thecountry’s workforce○Positiveimpact of solution:■Positively alter their self-perceptions\n20', metadata={'source': 'resources/cc3.pdf', 'page': 18}),
#  Document(page_content='■Creates an inclusive environment → wider population cangradually shift their attitudes towards PWDs and come to viewthem as valued members of society●The change in SG attitude towards disabled people across time○The “medical model” in theearlyyears sought to isolateand “fix”PWDs.○The pendulum swung towards a “social model” in the1980s and 1990swith the concomitant rise of human rights and welfare state systems.Attitudes towards PWDs●In the past○Lawmakers and governors → regarded the PWD issues to be domesticproblems,and conveniently adopted a hands-off approach○Family members of the PWD → treat them as embarrassments to thefamily, and quietly kept them away from the eyes of the public●The change: invasion of Western values in Asia○General public → becoming more vocal and assertive of their civilrights.○Governments → found themselves sandwiched between theinternational movement led by UNESCAP and the growing voices fromtheir own citizens●Construction of an inclusive society (the building blocks):○A Barrier-Free Society■those who areableto work are not prevented fromdoing so bysocial or physical barriers■Those who areunableto work have a decent qualityof life○Empowerment of the PWD■everyone is encouraged and empowered to participate andengage in all aspects of life in his/her society, to the best ofhis/her capability●Physical barriers○What are physical barriers:■Obstacles imposed by physical environment■Design features, or a lack thereof, of modern age equipmentand facilities that cause inconvenience or even impediment toPWD.○Reasons causing physical barriers:■A lack of awareness of the needs of PWD■Limited resources●Attitudinal barriers○Results from social attitudes toward PWD.○Common misconception that disabled people are objects of charity,rather than citizens with equal rights, opportunities, ability to contributeto and participate in society just as other non-disabled persons.\n21', metadata={'source': 'resources/cc3.pdf', 'page': 19}),
#  Document(page_content='○Impact of attitudinal barriers:■Hindered PWD in education, employment, housing,transportation, and willingness to integrate into society.●Government policies○Play the most important role in a country’s quest for an inclusivesociety ideology.○Government-led initiatives: implement codes, acts and mandates toensure equal rights of disabled persons.○Two basic policy approaches to disability worldwide■Equality of opportunity → outlaws discrimination■Equality of results → emphasises special needs over equalrights and mandating quotas.Lecture 5: AbortionReadings: AbortionVideosRoe v Wade: 1973 ruling that recognised a woman’s constitutional right to anabortion and legalised it nationwide in the US.Empirical background of abortion:-Rate of abortion is decreasing (24,000 in 1985 to 4029 in 2020 in SG)-More patients are married (69.75% in 1985 to 75.5% in 2002 in SG)-Less patients are teenagers (women under 20)-1279 in 2005, 1195 in 2009, 578 in 2013, 343 in 2016-Most common reason is to postpone or stop childbearing-Second most common is socioeconomic concerns ie. disruption of educationor employment, lack of support from father, cannot afford it-88% of abortions occur in the first 12 weeks of pregnancy-Abortion is prohibited after 24 weeks of pregnancy unless the mother’s life isin danger in SGStatistics about the effectiveness of banning abortions(Kramer 2016):-No. of unsafe abortions rise-Estimated 47,000 women die every year due to complications of unsafeabortions-Does not prevent it from happening-In Latin America and the Caribbean, where 97% of women live in countrieswhere abortion is restricted or banned, there is 44 abortions per 1000 women,26% higher than worldwide avgFacts:-Abortion is one of the safest surgical procedures for women-Risk of death is low and risk of major complications is less than 1% if done infirst trimester\n22', metadata={'source': 'resources/cc3.pdf', 'page': 20}),
#  Document(page_content='-Abortion is not more dangerous to a woman’s long term mental health thandelivering and parenting a child she did not intend to have or placing a babyfor adoption-No association between breast cancer and abortion-Abortion does not affect chances of becoming pregnant and having normalpregnancies in futureJudith Jarvis Thompson (arguing for abortion)-The right to life is not an absolute right-Having a right to life does not guarantee having either a right to be given theuse of or the right to the continued use of another’s baby-Abortion is morally permissible where pregnancy stems from rape and whereit is necessary to save the life of the mother-Objections: How about other cases?Don Marquis (arguing against abortion)-Killing someone deprives them of a “future like ours”-It deprives them of everything they will ever have or experience-A good future, one with happiness and good experience will not be possiblefor them-A future like ours - one which you and I have, which is one of value, will not bepossible for themObjections to the “future like ours” argument-It is less wrong to kill an old person, as they have lived most of their lives andhave less of a “future” ahead of them-Contraception and even abstinence is morally wrong as any act of notprocreating is depriving the potential for a “future like ours”-Severely mentally and physically disabled people have less chance of a“future like ours”, so is it less morally wrong to kill them?Virtue Ethics-Family of moral theories according to which morally right actions areexplained by the nature of a good life, and the good character traits(virtues)needed to live such a life.-Relevance to abortion - If we deem a person that chose to do an abortion ashaving acted virtuously, then by virtue theory, they have acted morally.(viceversa)Aristotle-Believed that virtues are necessary to have a good life or a life of“Eudaimonia”(flourishing), and that it is ultimately the exercise of reason-Argued that being able to reason well was the highest good for humans-This is because the ability to reason is a unique human function andseparates us from other beings-Held that highest human good cannot be attained without the virtues\n23', metadata={'source': 'resources/cc3.pdf', 'page': 21}),
#  Document(page_content="-To be virtuous, you need to be able to exercise excellent reasoning-Reasoning involves identifying the “mean” - between the 2 extremes ofcharacter, the “excess” and the “deficiency”-Reasoning consists of 2 kinds of abilities -  practical wisdom and theoreticalwisdom-Practical wisdomis the ability to reason well abouthow one ought to act inparticular circumstances-Theoretical wisdomis about theoretical things likesolving maths problemsor understanding how something works.-Relate it back to abortion(Is the person exercising reason excellently? Arethey assessing the meaning of their drives and emotions?)Al-Farabi-Held that the doctrine of the mean is crucial to virtue-Broke down practical wisdom to 4 components-Deliberative virtue or foresight, which is the ability to work out how toget what you want to get-Moral virtue, the ability to discover what is morally good-Natural virtue, that which enables a person to want a morally good end-Theoretical virtue, the ability to gain knowledge about the world-Relate it back to abortion (Is the person exercising practical wisdom indeciding abortion? Given the circumstances, is the person exercising all 4components of practical wisdom?)Readings(arguing against abortion)-What primarily makes killing wrong is neither its effect on the murderer nor itseffect on the victim's friends and relatives, but its effect on the victim.-Killing someone is wrong, primarily because the killing inflicts (one of) thegreatest possible losses on the victim-The loss of one's life deprives one of all the experiences,activities,projects, and enjoyments that would otherwise haveconstituted one's future.1.It is incompatible with the view that it is wrong to kill only beings who arebiologically human.2.The claim that the loss of one's future is the wrong-making feature of one'sbeing killed entails the possibility that the futures of some actual nonhumanmammals on our own planet are sufficiently like ours that it is seriously wrongto kill them.3.The claim that the loss of one's future is the wrong-making feature of one'sbeing killed does not entail, as sanctity of human life theories do, that activeeuthanasia is wrong.\n24", metadata={'source': 'resources/cc3.pdf', 'page': 22}),
#  Document(page_content='4.The wrongness of killing defended in this essay does straightforwardly entailthat it is prima facie seriously wrong to kill children and infants, for wepresume that they have futures of value.a.The claim that the primary wrong-making feature of a killing is the lossto the victim of the value of its future accounts for the wrongness ofkilling young children and infants directly; it makes the wrongness ofsuch acts as obvious as we actually think it is.-Since the reason that is sufficient to explain why it is wrong to kill humanbeings after the time of birth is a reason that also applies to fetuses, it followsthat abortion is prima facie seriously morally wrong.Lecture 6: EuthanasiaTypes of Euthanasia1.Voluntary:Requested by the person who undergoes it2.Involuntary:The person who undergoes it does notwant to do it3.Non-voluntary:The person who undergoes it is unableto indicate whetherhe/she wants to undergo euthanasiaActive VS Passive euthanasia (James Rachel)Approach 1: Acting (Active) vs not doing anything at all (passive)Approach 2: Human actions is the main cause of death vs injury/disease is themain cause of deathActive Euthanasia:-Approach 1: Whether anything is done that contributes to the person;s death-Approach 2: Main cause of death is human actionPassive Euthanasia:-Approach 1: Nothing at all is done that contributes to the person’s death-Main cause of death is not human action but instead injury or disease4 concepts/criterion for death:1.Are you dead upon irreversible cessation of your heartbeat and respiration?Rachel: Life support machine could keep your heart beating and keep youbreathing and in such situations, are you dead or alive?2.Are you dead upon irreversible cessation of spontaneous heartbeat andrespiration?3.Are you dead if you irreversibly lose consciousness and your whole brain isdead?“Irreversible coma” is defined as:-Absence of any detectable brainstem reflexes-Absence of neurological drive to breathe even when high levels of CO2are allowed to accumulate in blood circulation-Responses to extreme pain, alongside a flat line ECG\n25', metadata={'source': 'resources/cc3.pdf', 'page': 23}),
#  Document(page_content="4.Are you dead if you reversibly lose consciousness and your brain is dead?Ethical considerations: Traditional vs Radical ViewTraditional view:-Passive Euthanasia is morally permissible and should be legally permitted.Active Euthanasia is not morally permissible and should be illegalRadical view:-There are some cases where active euthanasia is morally obligatoryTraditional View:-Theological reasons: Tend to be the same as the ones against suicide-Non-theological reasons: Appealing to moral feelings or intuitionsRachel: Fundamentally no difference between killing and letting dieGreedy Cousin Analogy:(Smith killed the child bydrowning him VS Jones lettingthe child die as he watches him drown)Bare Difference Argument:-Definition: Bare difference between killing and letting die doesn't make amoral difference-People tend to think that killing is worse than letting die, but this analogyshows us that it isn't necessarily so-This suggests that our moral feelings and intuitions are not necessarily alwayswell supportedDifferences between active and passive euthanasia:1.There are situations in which passive euthanasia is morally permissible andactive is not2.There is no morally defensible distinction between passive and activeeuthanasia3.Any situation in which passive euthanasia is permissible is also one in whichactive euthanasia is permissible4.Active euthanasia is sometimes permissibleObjection(s) against Voluntary Active Euthanasia:-Slippery slope: There will be an increasing callousness towards killing and thiswill lead to an increase in involuntary euthanasia rates-Counter Argument:1.Safeguards can be instituted to prevent this2.If we are assessing based on whether euthanasia is ethical or not thenthis objection wil not count because we are not discussing the moralityof it. Question of whether it is moral or not is separate from thequestion of whether it should be legal.\n26", metadata={'source': 'resources/cc3.pdf', 'page': 24}),
#  Document(page_content='Utilitarianism:-Consequentialist theory (i.e., whether the act is moral or not, is decided basedon the consequences)-An action is morally required if it maximisesoverallwell-being(i.e., when itdoes more to improve overall well-being than any other action you could’vedone in the circumstances)-Theory of impartiality – it’s objective is that no one is favoured over anotherfor some particular reason; reflect the equality of all human beings-Two things to avoid: Absence of well-being and the opposite of well-being(e.g., suffering)Utilitarianism can be problematic because:-Some of the original advocates were arguably tied up with a colonialist andimperialist past and with related issues like race and slavery.-Such a path is not entirely proven. Even if so, the validity of the theory shouldnot be dependent on the history of its proponents.Well Being (Philosophers):Jeremy Bentham and John Stuart Mill-They were some of the first proponents of utilitarianism-Well-being consist solely of pleasurePeter Singer (Contemporary Philosopher)-Well-being is a satisfaction of desiresWell being is good and valuable:-Overall well-being in the net well-being of all individuals affected by an action-Net well-being is the net balance of benefits and losses to well-beingproduced by an action-Everyone’s well-being counts equallyHinduismPurusarthas has four set of values:1DharmaThe ethical or moral (in action, or in character; often translatedas “duty”)2ArthaEconomic wealth3KãmaPleasure4MoksaLiberation from rebirth and imperfection (a sort of salvation)Three aspects of Hindu philosophy are in line with euthanasia\n27', metadata={'source': 'resources/cc3.pdf', 'page': 25}),
#  Document(page_content='1KarmaNet outcome of the good and bad deeds that aperson has done in their lifetime; Bad karma =Unable to achieve moksha2LiberationBeing freed from the cycle of reincarnation3Ahimsa(non-violence)Non-violence, non-injury or non-killing; Cannotcommit acts of violence in thought, word or deedagainst other living creaturesReadingsJAMES RACHEL-Process of being “allowed to die” can be relatively slow and painful whereasbeing given a lethal injection is relative quick and painless-The bare difference between killing and letting die does not, in itself, make amoral difference (i.e., If a doctor lets a patient die, for humane reasons, he isin the same moral position as if he had given the patient a lethal injection forhumane reasons)\n28', metadata={'source': 'resources/cc3.pdf', 'page': 26}),
# ...
#  Document(page_content="●Democratic despotism○Allowing too much emphasis on individualism results in negation ofcivic duties. If you are allowed to do whatever you want whenever itsuits you, it doesn't matter if it's good for society.○High chance to abandon their civic responsibilities and bully others inthe name of liberty○Leads to chaos and riots in the name of liberty and individual freedom■6 Jan 2021 → in the US there was an angry mob that stormedthe government building as they thought they represented themajority and had the liberty and freedom to do whatever theywant. Wanted to challenge Joe Biden’s presidency as they wereTrump supporters\n●Dangers of totalitarian regimes○Controls people by deceiving them. Seek towards ignorance, freedomis overrated and war is peace so let's not criticise the fact that we are inwar.\n43", metadata={'source': 'resources/cc3.pdf', 'page': 41}),
#  Document(page_content='○Paradoxical Logic deceives their citizens thus controlling citizens in theprocess.●Newspeak and double-speak are basically how the government deceives theircitizens.○E.g. Nazi Germany exterminating the Jews managed to deceive thegerman public that exterminating the jews was an act of duty andmorality.●Thought Crime○Thinking becomes a crime.○If you make critical thinking a crime, anything that criticises thetotalitarian government is wrong.\n●Toxic Mix of idealogy and terror (Totalalirian Regime)○Start with ideology, all ideologies claim the truth of something.Combined with terror (e.g. putting opposition in death camps if they goagainst regime) leads to acceptance of terror as justifiable punishment.\n44', metadata={'source': 'resources/cc3.pdf', 'page': 42}),
#  Document(page_content='●Summary\nAdditional ReadingsDifferent forms of democracy:●Pure/direct democracy○Everyone votes for everything (every decision to be made bygovernment), i.e. everyone has to vote for any decision to be made●Representative democracy\n45', metadata={'source': 'resources/cc3.pdf', 'page': 43}),
#  Document(page_content='○People elect officials to represent them in legislative votes on mattersaffecting the population.○Much more common○More practical than pure/direct democracyRepresentative democracyis thought to be themoreeffectiveofthe 2●Individuals who govern a society and in other ways help a society function arethe individuals who have theappropriate talents,skills, and knowledge to doso.●The masses of people are, overall, too uninformed, too uneducated, and toouninterested to run a society themselves.○Positiveeffects of representative democracy■Allows for “the cream to rise to the top” → people who actuallygovern a society are the most qualified to perform this essentialtask.”■I.e. the people who are making the decisions actually knowwhat is best for this society/ what best represents theinterests of the people.■Sometimes people are not educated enough or simply donot care about certain issues.○Negativeeffects of representative democracy■More often an ideal rather than a reality■Oftentimes the people who are elected are corrupt, not suited forthis role, or are swayed by lobbying as they contribute to theirpolitical campaigns in terms of money. E.g. NRA, gun violence inamerica.Voting●The defining feature of representative democracy is voting in elections.●When the United States was established more than 230 years ago, most ofthe world’s governments were monarchies or other authoritarian regimes(discussed shortly).●Like the colonists, people in these nations chafed (irritated/ discontented)under arbitrary power.○The example of the American Revolution and the stirring words of itsDeclaration of Independence helped inspire the French Revolution of1789 and other revolutions since, aspeople aroundthe world havedied in order to win the right to vote and to have political freedom.Imperfections of democracy\n46', metadata={'source': 'resources/cc3.pdf', 'page': 44}),
#  Document(page_content='●Decision-making process can be quite slow and inefficient●Decisions may be made for special interests and not “for the people”○Pervasive inequalities of social class, race and ethnicity, gender, andage can exist.●Not all democracies have all people enjoying the right to vote.○In the United States: African Americans could not vote until after theCivil War, with the passage of the 15th Amendment in 1870, andwomen did not win the right to vote until 1920, with the passage of the19th Amendment.Freedom of democracies●People in democracies are also in general more free compared to those not indemocracies.●Thefreestnations: North America, Western Europe,and certain other parts ofthe world●Theleast free: Asia, the Middle East, and Africa.Monarchies:Definition: A Monarchy is a political system in which power resides in a single familythat rules from one generation to the next generation.●Enjoys traditional authority●Most monarchs command respect because their subjects bestow this type(traditional authority) of authority on them.●Other monarchs ensured respect through arbitrary power and even terror.●Royal families still rule today, but their power has declined from centuries ago.○Today the Queen of England holds a largely ceremonial position, buther predecessors on the throne wielded much more power.○Historical change →  fromabsolute monarchies to constitutionalmonarchies(Finer, 1997).Absolute monarchy■Royal family claims a divine right to rule and exercisesconsiderable power over their kingdom.■Common in both ancient (e.g., Egypt) and mediaeval (e.g.,England and China) times.In reality, the power of many absolute monarchs was not totallyabsolute (became constitutional monarchies)■Kings and queens had to keep in mind the needs and desires ofother powerful parties, including the clergy and nobility.■Over time, absolute monarchies gave way to constitutionalmonarchies → royal family serves a symbolic and ceremonialrole and enjoys little, if any, real power.\n47', metadata={'source': 'resources/cc3.pdf', 'page': 45}),
#  Document(page_content='■Instead the executive and legislative branches ofgovernment—the prime minister and parliament in severalnations—run the government, even if the royal family continuesto command admiration and respect.■Constitutional monarchies exist today in several nations,including Denmark, Great Britain, Norway, Spain, and Sweden.Authoritarianism and Totalitarianism:Authoritarianism→ to political systems in which anindividual or a group ofindividuals holds power, restricts or prohibits popular participation in governance,and represses dissent.●China, RussiaTotalitarianism→ to political systems that includeallthe features of authoritarianismbut are evenmore repressiveas they try to regulateand control all aspects ofcitizens’ lives and fortunes.●People can be imprisoned for deviating from acceptable practices or mayeven be killed if they dissent in the mildest of ways.●North Korea, AfghanistanThese forms of governments are unstable politically●These governments don’t really hold power invested in them by the people(the people don’t believe in them)●They maintain power through fear and oppression.●The populations of these governments do not willingly lend their obedience totheir leaders and realise that their leaders are treating them very poorly●Populations in authoritarian and totalitarian states are more likely thanpopulations in democratic states to want to rebel.○Sometimes they do rebel, and if the rebellion becomes sufficientlymassive and widespread, a revolution occurs.○In contrast,populations in democratic states usuallyperceive that theyare treated more or less fairly and, further, that they can change thingsthey do not like through the electoral process. Seeing no need forrevolution, they do not revolt.\n48', metadata={'source': 'resources/cc3.pdf', 'page': 46}),
#  Document(page_content='Lecture 10: Freedom of speechOutline for Lecture 10:1)Meaning of “Free Speech”2)What are Universal Regulations of Free Speech?3)What is Harm Principle? And what are its Problems?4)What is Offence Principle?5)Flow Diagram for Harm Principle & Offence Principle6)Paradox of Tolerance7)Process of Violence8)Summary9)Additional Readings1)Meaning of “Free Speech”Free Speech (aka Freedom of Speech) is theFreedomof Expression.4 Types of Free Speech1.Verbal●Mainly what isSaidorWritten●E.g. Hate Speech, Feminist Speech, Published Books, PublishedArticles2.Symbolic●Speech without Words●E.g. T-shirts with Political Messages, Flying Flags, Uniforms, Banners,etc.3.Associations●Speech through Associations●E.g. Religious Associations, Conservative Associations, LiberalAssociations, Ethic / Racial Communities, etc.4.Autonomy●Speech as Independent Action●E.g. Riots, Resistance Movements, Peaceful Assembly, evenPornography, etc.\n49', metadata={'source': 'resources/cc3.pdf', 'page': 47}),
#  Document(page_content='4 Reasons why Free Speech is Important1.Equality (Among Citizens)●Citizens can engage on an equal basis2.Autonomy (Self-Determination)●Citizens can decide their own actions3.Political Freedom (For All Citizens)●Citizens have political choice4.Promoting Truth (Through Free Exchange of Ideas)●Free Exchange of IdeasThese 4 Reasons above are also why undemocratic states (countries),especiallytotalitarian states, prohibit free speech.E.g. Nazi Germany, Present-Day North Korea, Present-Day RussiaALLdemocracies regulate Free Speech to some extent(or level)Some democracies allow more(US and Western Europe)and others allow less(Singapore).No such thing as absolute Free Speech.●Liberal Democracieslike US and Western Europe●Limited Democracieslike Singapore2)Universal Regulations of Free SpeechCircumstances when Free Speech is regulated (even in Liberal DemocraticStates)\n50', metadata={'source': 'resources/cc3.pdf', 'page': 48}),
#  Document(page_content='1.True Threats●Expressions of intent toharm / use violenceagainsta specificindividual or group●E.g. Using actual words or symbols by Hate Groups2.Punishable Incitements●Inciting someone elseto useviolenceagainst a specificindividualgroup●Can be verbal or symbolic●E.g. Leaders of Hate Groups/Movement or Terrorist Groups●Inciting someone to use violence is also a crime and you will bepunished as well3.Fighting Words●Provocative statementsto get someone to fight withyou●E.g. Hateful racist remarks, Neo-Nazis marches4.Harassment●Verbalorsymbolic expressions of hate or insultthatalters the targetedindividuals’ way of life●E.g. Workplace sexual harassment5.Facilitating Criminal Conduct●Providing Information or Logisticsto someone to facilitatetheir hatecrime.●E.g. Collaborating with Hate Groups or “Regular” German Citizensreporting on the whereabouts of Jews during Nazi Regime6.Bias Crimes●Verbal or symbolic speech that incites violence due to a bias againstan individual or group●E.g. Anti-LGBTQ bias, Anti-Women bias3)Harm PrincipleHarm Principle is a measure to determine the extent of harm done to a victimby unregulated speech.●Establishes whether“Harm”can belitigated(takelegal action against)●“Harm” refers to directviolationof anindividual’srightdue to hate speech●E.g. Bodily harm done to victim, Loss of job or Inability to secure a job, forcedto change lifestyle, or even Death (murder / suicide)Harm Principle does NOT concern itself with:●The Morality or Immorality of Free Speech○Socially right or Wrong○E.g. In Pornography,only when someone is actually harmed\n51', metadata={'source': 'resources/cc3.pdf', 'page': 49}),
#  Document(page_content='Problems with Harm Principle:Case of Neo-Nazi March●In 1977, Neo-Nazi March through Jewish communities in Skokie, Illinois,United States, dress in Nazi uniforms & Swastikas●Neo-Nazi practicing their right to symbolic-free speech asNO WORDSwereexchanged●Jewish people were deeply offended but the court ruled in favour of theNeo-Nazi right to Free Speech a s they believed that Strict Hate Laws wouldresult in worst acts being committed by the Neo-Nazis so by letting themmarch without violence and peacefully, it would be better.4)Offence PrincipleOffence Principle is only relevant when hate speech does not qualify for the“Harm principle”.●The two are Mutually Exclusive; if not Harm Principle, only then OffencePrinciple can come inOffence Principle is intended to censure(publiclydisapprove)hate speech.●Offence Principles are best for cases ofpsychologicaloremotionalharm, asthese cannot be proved well enough to qualify forHarm Principle.●E.g. In the case of the Neo-Nazis, the Jewish community was able toestablish offence caused by Neo-Nazi march, therefore was successful inshaming the Neo-Nazis publicly.5.Flow Diagram for Harm Principle & Offence Principle\n52', metadata={'source': 'resources/cc3.pdf', 'page': 50}),
#  Document(page_content="6.Paradox of ToleranceIf Democracies→Have Unlimited Tolerance UnregulatedFree Speech(Hypothetically only because in reality it is not unlimited)→It will lead to huge / rapidincrease in Hate Groups→and these group will beintolerance of difference viewsfrom other people (Don’t accept other people’s views that are not the same as theirs→ Hence,Paradox of Tolerance occurs, wheretoo muchtolerance leads tointoleranceby the different groups.●Paradox of Tolerance reflects Plato’s fear of democracies●Paradox of Tolerance is an idea forwarded by Karl Popper●Present-Day liberal democracies do regulate free speech, but regulationshave higher thresholds●“There is no such thing as [completely] free speech”, even in liberaldemocracies - Stanley Fish, Stanford Encyclopaedia of Philosophy7.Process of ViolenceStarts with Hate Speech(Justification of Hate againstparticular groups)→Creating Discriminating Narratives(Distributing HatefulViews through SocialMedia)→ Resulting in Outcomes of Violence(PhysicalViolence)8.Summary1.'Speech' means more than just what is said, Speech also includes symbols such ast-shirts we wear or flags we fly, associations we join as these are indirect ways for usto 'speak' through our association with a group or movement, and finally, speech alsoincludes acts of autonomy.2.All states (countries) impose regulations on free speech--This includes oven liberaldemocracies. The only difference is in the threshold of limitations. For example,liberal democracies (like the US) allow less regulations than limited democracies (likeSingapore), but they still regulate free speech.3.There are six major universal criteria for regulating free speech. And those are truethreats, punishable incitements, fighting words, harassment, facilitating criminalconduct and bias crime.4.Harm principle is the criteria to determine whether hate speech has caused harm andif it can be litigated. Again, the threshold for harm principle is a lot higher in theUnited States than it would be in Singapore.5.Offence principle was created, we've learned, to censure (publicly disapprove) hatespeech. And this is applied when hate speech doesn't qualify for harm principle andcannot be litigated.\n53", metadata={'source': 'resources/cc3.pdf', 'page': 51}),
#  Document(page_content='6.There are two main dangers of unregulated free speech, the paradox of toleranceand the process of violence.Quotes to refer to if Exam asks about them:(Probablynot important)\n9. Additional ReadingsJohn Stuart Mill’s Harm Principle:If the arguments of the present chapter are of any validity, there ought to exist thefullest liberty of professing and discussing, as a matter of ethical conviction, anydoctrine, however immoral it maybe considered. (1978, 15)Simply meaning / arguing that:Any doctrine / topic / matter should be allowed the light of day no matter howimmoral it may seem to everyone else.\n54', metadata={'source': 'resources/cc3.pdf', 'page': 52})]

# %% [markdown]
# #### Step 1b: Document Chunking & Split
# When sending a context for LLM for reasoning/inference, its best not to dump in the entire documents as this will cause more tokens to be consume and sometimes can be slow or inaccurate. Hence there is a need to split the document into chunks which will be stored/index using Vector Store/Databases.
#
# When parsing the context, we only need to find relavent chunks from the vector store/DB and send over to LLM. This will make the response much more accurate and faster.
#
# Link: https://python.langchain.com/v0.1/docs/modules/data_connection/document_transformers/character_text_splitter/

# %%
from langchain_text_splitters import CharacterTextSplitter

text_spliter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=400)
course_info_chuncks = text_spliter.split_documents(course_info)
course_content_chuncks = text_spliter.split_documents(course_content)

print("Course Info Chunks", len(course_info_chuncks))
print("Course Content Chunks", len(course_content_chuncks))
# Out:
# Course Info Chunks 1
# Course Content Chunks 53

# %% [markdown]
# combine both documents chunks into single collections

# %%
allchunks = []

allchunks.extend(course_info_chuncks)
allchunks.extend(course_content_chuncks)

print("N Combined Chunk for both documents: ", len(allchunks))
# Out:
# N Combined Chunk for both documents:  54

# %% [markdown]
# #### Step 2: Vector Stores, Databases, & Indexing
#
# Now that the chucks from both documents are ready, we will now create an index and store them into a database called Vector Store/Vector Database (Knowledge Base). This is a special database which uses text embedding model which translate a bunch of text into vector.
#
# This vector will be useful for search or comparison for similar text given. That's is how the relavent chunk of documents is retrieved when we pass in a query so the vector store/DB could return the relavent chunks of document which will later being passed to LLM as a context/knowledge.
#
# In this exercise, we will be using the Facebook AI Similarity Search (FAISS) as vector store while the AzureOpenAI Text Embedding Model will be use for the text to vector conversion process. Note that FAISS is considered a local database, same goes to ChormaDB while Pinecone and AzureAISearch is considered a cloud-based vector store which uses API calls.
#
# - AzureOpenAI Text Embedding Model: https://python.langchain.com/v0.1/docs/integrations/text_embedding/azureopenai/
# - Facebook AI Similarity Search (FAISS) :
#     - Vector Database
#     - Docs: https://api.python.langchain.com/en/latest/vectorstores/langchain_community.vectorstores.faiss.FAISS.html
#
# *__Acknowledgement__: This access key and resources are supported by NTU EdeX Teaching and Learning Grants 2023-2024 (Call 1)  from the Center for Teaching, Learning & Pedagogy (CTLP) for the project titled "AskNarelle". Please do not share and distribute to other parties*
#
# ##### Other Vector Stores/Databases
# - ChromaDB
#     - Docs: https://python.langchain.com/v0.1/docs/integrations/vectorstores/chroma/
# - Pinecone:
#     - Docs: https://python.langchain.com/v0.1/docs/integrations/retrievers/self_query/pinecone/
# - AzureAISearch :
#     - Docs: https://learn.microsoft.com/en-us/azure/search/search-what-is-azure-search

# %%
from langchain_community.vectorstores import FAISS
from langchain_openai import OpenAIEmbeddings

# %%
from langchain_openai import OpenAIEmbeddings
load_dotenv(override=True)
new_text_embedding =  OpenAIEmbeddings(api_key=os.environ['OPENAI_API_KEY'])
new_db = FAISS.load_local("resources/db", new_text_embedding, allow_dangerous_deserialization=True)

docs = new_db.similarity_search("What is this course all about?", k=5)

for d in docs:
    print(d)
    print("\n")
# Out:
# page_content='Lecture 1:Why do ethics and civics matter to everyone/ what is the purposeof studying this course?-Learn how to engage in a reasoned discussion about issues in ethics and civics(which is what we should do in a multicultural world)-Learn to critically examine the various reasons that all of us may have, given ourdifferences, to believe or act with regard to ethical issues-Different people have different ideas and conceptions as to how they should livewhether as individuals or as citizens-We belong in overlapping societies (e.g. Singapore society, Internet society, schoolsocieties)-Reflecting on the kinds of actions that either would or would not contribute to how wethink we should live, both as an individual and as a citizen, we find that this includesa wide range of concerns-Provide some direction on how we can better come up with and/ or evaluate ourreasons in all these situations and more (these situations do matter to us or others)Convincing others why we should be allowed to live our lives the waywe want:-Give reasons to explain/ justify why we think what we think-Sometimes these reasons are good or badCourse Expectations:-Identify the morally relevant features of situations, decisions and policies-Explain your moral responsibilities to actively participate in activities that strengthenyour local and global communities-Critically assess the civic structures and institutions of your communities and yourrole in them-Make well-informed arguments on some major contemporary issues-Apply ethics and civics concepts to the Singapore context-Remain open to reasons for how others might be negatively affected or how youyourself might be negatively affected → through this, we can find out why thingsmatter to us or why things matter to others\n2' metadata={'source': 'resources/cc3.pdf', 'page': 0}
#
#
# page_content='CC000 3 Ethics and Civics in a Multicultural World  \n        \nAcademic Year  AY202 2/23 \nAcademic Units  2AUs  \nTutorial Hours  26 \n \nCOURSE AIMS  \nThis course aims to equip students with the necessary philosophical foundations to understand theories of ethics \nand subsequently apply those theories to real -life scenarios and issues. It also aims to enable students to understand \nand critically assess th e civic institutions that structure their local and global communities. To these ends, the course \nwill examine the nature of ethics, its understanding across different cultures, and how it is manifested in concepts, \nsocial structures, and governance instit utions.  \n \nTopics to be explored include human rights, democracy, freedom of speech  and inequality. The rights and duties of \ncitizenship shall be a unifying theme. Students will think through assumptions they hold on all of these matters. \nThey will be provided with the tools to understand various and even contradictory perspectives on these important \nissues. There will be a substantial amount of time devoted toward understanding Singapore’s own institutions and \nideologies, which are of course products specific to the country’s own unique historical and geo -political \ncircumstances. We expect t hat students will have a better appreciation of the country’s institutions after reading \nthe module.  \n \nINTENDED LEARNING OUTCOMES  \nBy the end of this course, you should be able to:  \n1. Identify the morally relevant features of situations, decisions, and policies;  \n2. Explain your moral responsibilities to actively participate in activities that strengthen your local and global \ncommunities;  \n3. Critically assess th e civic structures and institutions of your communities and your role in them;  \n4. Make well -informed arguments on some major contemporary issues.  \n5. Apply ethics and civics concepts to the Singapore context.  \n \nCOURSE CONTENT  \n1. Introduction – What is Ethics, Civics, Multiculturalism and how is this relevant to you?  \n2. Reasoning for ethics and civics + Logic Quiz  \n3. Human Rights Part 1: Human Trafficking  \n4. Human Rights Part 2: Disability  \n5. Reproduction Ethics : Abortion  \n6. Ethics of Death and Dying : Euthanasia and Assisted Suicide  \n7. Equality & Meritocracy  \n8. Multicultralism  \n9. Political Systems: Types, Features, and Moral Justifications  \n10. Free Speech: Meanings, Limitations, and Implications  \n \nREFERENCES  \n1. Russ Shafer -Landau, “What is Morality?” pp. 1 -6 from Living Ethics  (US: Oxford University Press, 2019).  \n2. Al-Farabi, excerpts from “The Attainment of Happiness” pp. 113 -119 from Introduction to World Philosophy  \n(US: Oxford University Press, 2009).  \n3. Teo You Yenn, This is What Inequality Looks Like , pp. 41 -90 (Singapore: Ethos Books, 2018).' metadata={'source': 'resources/CC0003-Outline-AY2021-S28631bdc2-fab3-4039-a923-723ef29f6e8e.pdf', 'page': 0}
#
#
# page_content='●Studying ethics and civics at university level is primarily aboutpithy(expressive) sayings or which-person-said-what → relying on quotesstops you from reasoning independently-What doing ethics and civics actually mean:●No one cares about your belief or opinion, but they care about whether youshould have that belief●Care about opinions and beliefs that have undergone a process of anexchange of reasons with others (i.e. what matters is reasonable belief)-Questions to ask yourself when doing ethics and civics:●Why should others take seriously why you believe it is the best way to live orthe best way to organise and participate in a state?●What sort of reasons can you offer others that they should care about howyou think you should live your life or how society should be run?-Always engaged in ethics and civicsEthics:-Normative ethics: Theory-led approach●Ethical theory: Involves a set of principles that are meant to be applieduniversally to anyone and what they should do in general.●Apply ethical theories to ethical issues or ethical scenarios●Pick ethical theories that make the most sense and is the most reasonable ofour individual and collective lived experiences of the world●Make sure that the ethical theory you choose is the most justified and has themost explanatory power-Applied ethics: Circumstances-led approach●Looks into the who, what, when, where, why of a situation●Who: Who are the actors of a given scenario, and who are the ones receivingthe act → asking this helps us consider the context/ background of the actorsand receivers●What: Is the evidence that you’re looking atmorallyrelevant?●When: Time of action●Where: Place where action happened●Why: Look into causes and conditions of scenario●Theory-led approach and circumstances-led approach should work together-Studying ethics allows you to communicate with others about ethical issues-As students, we must pay attention to the details of everyday scenarios and becomesensitised to what might be ethical circumstances as we go about our lives\n5' metadata={'source': 'resources/cc3.pdf', 'page': 3}
#
#
# page_content='Civics:-Studying civics allows you to communicate with others about civic issues-Looks into what sort of state is in question, and how citizens relate to it and to eachother-State:●Unique, historical, stable site●Have economic, political and social relations●Characteristics of a state and citizens’ corresponding rights and dutiesdepends on state’s history, people, culture, goods, services, forms ofgovernment, values of governmentMoral philosophy:-Has a subject matter, morality, and a method, philosophical reasoning-Ideas in moral philosophy are very important-Ideas should be studied by anyone who wants to think seriously about morality-Should gain understanding of a view in its subtlety and complexity before dismissingit-Globalisation (Western culture are widespread in the world) → should be aware ofthe major traditions of Western moral philosophy to understand world history,literature, culture-Should not just focus on Western theories of morality, but also explore othertraditions of ethicsTheories:-Utilitarianism: Principle of Utility → act in a way that maximises overall pleasure (Theright thing to do is always to ensure that the action that one takes has theconsequence of increasing the total amount of pleasure in the universe)Claims:-Normative claims: what we ought to do, or should do●Morally relevant reasons support normative claims-Descriptive claims: a particular state of affairs (what is happening in the situation e.g.Tom helped Brenda)\n6' metadata={'source': 'resources/cc3.pdf', 'page': 4}
#
#
# page_content='-Democracy: People of the state are the ones with the ultimate power●Democratic society = collective project to be carried out by all its citizens,while also taking into account others who might be affected by this project-Monarchy: Monarch (king or queen) has ultimate power-Regression analysis: aim to establish a conditional relation between independent anddependent variables-Moral philosophy:●Main definition: the practice of reflecting philosophically on morality●Practical subject with many significant and important theoretical elements●Help you develop your own moral outlook of life (i.e. help you come to asharper sense of what does and does not matter from a moral point of view)●Form a view of what considerations do, and do not, need to be takenseriously●How we should develop our reasoning, attention and emotions●Help you think through nature of your relationships with other people, andwith other things of value (e.g. animal world, natural environment)●Help you think about how you should use your talents and energy●Help you decide what your goals in life should be●Looks into how you should try to influence and/ or educate those around youConcepts:Both ethics and civics:-Ethics and civics = exchange of reasons (care about quality of reasons, not quantity)-Ethics and civics = currency of any discussion-Ethics and civics are multicultural → we are constantly engaging in an exchange ofreasons with others who are culturally dissimilar or different from us - and weconstantly have to adapt our beliefs and actions as a result of such an exchange-As we change, the various cultures that each of us make up change and multiply-Ethics and civics look into the level of reasons, not the level of beliefs and opinions-Doing ethics and civics doesNOTmean:●Merely sharing opinions or beliefs without rational support●Finding a fancy word or phrase for something●Finding an -ism that sounds cool/ resonates with you (you should considerdifferent theories, even though you may not agree with them)\n4' metadata={'source': 'resources/cc3.pdf', 'page': 2}

# %% [markdown]
# #### Step 3: Perform Similarity Search based on user Query
#
# Now that you have created a vector database by feeding in the combine chunks for both documents.
# You have also generated a retrieval object which will return top 3 most relavent chunks of document based on a query.
# Now, its time to verify the retrieval and try to search relavent chunk of documents based on query given.

# %%
query = "What is the course all about?"
result = new_db.similarity_search(query, k=3)

print("Total chunck returned: ", len(result))
print(result[0])


print("\n\n=====================================================================")
for r in result:
    print(r.page_content)
    print("  ### [Source Document: ", r.metadata['source'], "]")
    print("\n     ------------------------------------        \n")
print("=====================================================================")
# Out:
# Total chunck returned:  3
# page_content='Lecture 1:Why do ethics and civics matter to everyone/ what is the purposeof studying this course?-Learn how to engage in a reasoned discussion about issues in ethics and civics(which is what we should do in a multicultural world)-Learn to critically examine the various reasons that all of us may have, given ourdifferences, to believe or act with regard to ethical issues-Different people have different ideas and conceptions as to how they should livewhether as individuals or as citizens-We belong in overlapping societies (e.g. Singapore society, Internet society, schoolsocieties)-Reflecting on the kinds of actions that either would or would not contribute to how wethink we should live, both as an individual and as a citizen, we find that this includesa wide range of concerns-Provide some direction on how we can better come up with and/ or evaluate ourreasons in all these situations and more (these situations do matter to us or others)Convincing others why we should be allowed to live our lives the waywe want:-Give reasons to explain/ justify why we think what we think-Sometimes these reasons are good or badCourse Expectations:-Identify the morally relevant features of situations, decisions and policies-Explain your moral responsibilities to actively participate in activities that strengthenyour local and global communities-Critically assess the civic structures and institutions of your communities and yourrole in them-Make well-informed arguments on some major contemporary issues-Apply ethics and civics concepts to the Singapore context-Remain open to reasons for how others might be negatively affected or how youyourself might be negatively affected → through this, we can find out why thingsmatter to us or why things matter to others\n2' metadata={'source': 'resources/cc3.pdf', 'page': 0}
#
#
# =====================================================================
# Lecture 1:Why do ethics and civics matter to everyone/ what is the purposeof studying this course?-Learn how to engage in a reasoned discussion about issues in ethics and civics(which is what we should do in a multicultural world)-Learn to critically examine the various reasons that all of us may have, given ourdifferences, to believe or act with regard to ethical issues-Different people have different ideas and conceptions as to how they should livewhether as individuals or as citizens-We belong in overlapping societies (e.g. Singapore society, Internet society, schoolsocieties)-Reflecting on the kinds of actions that either would or would not contribute to how wethink we should live, both as an individual and as a citizen, we find that this includesa wide range of concerns-Provide some direction on how we can better come up with and/ or evaluate ourreasons in all these situations and more (these situations do matter to us or others)Convincing others why we should be allowed to live our lives the waywe want:-Give reasons to explain/ justify why we think what we think-Sometimes these reasons are good or badCourse Expectations:-Identify the morally relevant features of situations, decisions and policies-Explain your moral responsibilities to actively participate in activities that strengthenyour local and global communities-Critically assess the civic structures and institutions of your communities and yourrole in them-Make well-informed arguments on some major contemporary issues-Apply ethics and civics concepts to the Singapore context-Remain open to reasons for how others might be negatively affected or how youyourself might be negatively affected → through this, we can find out why thingsmatter to us or why things matter to others
# 2
#   ### [Source Document:  resources/cc3.pdf ]
#
#      ------------------------------------
#
# CC000 3 Ethics and Civics in a Multicultural World
#
# Academic Year  AY202 2/23
# Academic Units  2AUs
# Tutorial Hours  26
#
# COURSE AIMS
# This course aims to equip students with the necessary philosophical foundations to understand theories of ethics
# and subsequently apply those theories to real -life scenarios and issues. It also aims to enable students to understand
# and critically assess th e civic institutions that structure their local and global communities. To these ends, the course
# will examine the nature of ethics, its understanding across different cultures, and how it is manifested in concepts,
# social structures, and governance instit utions.
#
# Topics to be explored include human rights, democracy, freedom of speech  and inequality. The rights and duties of
# citizenship shall be a unifying theme. Students will think through assumptions they hold on all of these matters.
# They will be provided with the tools to understand various and even contradictory perspectives on these important
# issues. There will be a substantial amount of time devoted toward understanding Singapore’s own institutions and
# ideologies, which are of course products specific to the country’s own unique historical and geo -political
# circumstances. We expect t hat students will have a better appreciation of the country’s institutions after reading
# the module.
#
# INTENDED LEARNING OUTCOMES
# By the end of this course, you should be able to:
# 1. Identify the morally relevant features of situations, decisions, and policies;
# 2. Explain your moral responsibilities to actively participate in activities that strengthen your local and global
# communities;
# 3. Critically assess th e civic structures and institutions of your communities and your role in them;
# 4. Make well -informed arguments on some major contemporary issues.
# 5. Apply ethics and civics concepts to the Singapore context.
#
# COURSE CONTENT
# 1. Introduction – What is Ethics, Civics, Multiculturalism and how is this relevant to you?
# 2. Reasoning for ethics and civics + Logic Quiz
# 3. Human Rights Part 1: Human Trafficking
# 4. Human Rights Part 2: Disability
# 5. Reproduction Ethics : Abortion
# 6. Ethics of Death and Dying : Euthanasia and Assisted Suicide
# 7. Equality & Meritocracy
# 8. Multicultralism
# 9. Political Systems: Types, Features, and Moral Justifications
# 10. Free Speech: Meanings, Limitations, and Implications
#
# REFERENCES
# 1. Russ Shafer -Landau, “What is Morality?” pp. 1 -6 from Living Ethics  (US: Oxford University Press, 2019).
# 2. Al-Farabi, excerpts from “The Attainment of Happiness” pp. 113 -119 from Introduction to World Philosophy
# (US: Oxford University Press, 2009).
# 3. Teo You Yenn, This is What Inequality Looks Like , pp. 41 -90 (Singapore: Ethos Books, 2018).
#   ### [Source Document:  resources/CC0003-Outline-AY2021-S28631bdc2-fab3-4039-a923-723ef29f6e8e.pdf ]
#
#      ------------------------------------
#
# ●Studying ethics and civics at university level is primarily aboutpithy(expressive) sayings or which-person-said-what → relying on quotesstops you from reasoning independently-What doing ethics and civics actually mean:●No one cares about your belief or opinion, but they care about whether youshould have that belief●Care about opinions and beliefs that have undergone a process of anexchange of reasons with others (i.e. what matters is reasonable belief)-Questions to ask yourself when doing ethics and civics:●Why should others take seriously why you believe it is the best way to live orthe best way to organise and participate in a state?●What sort of reasons can you offer others that they should care about howyou think you should live your life or how society should be run?-Always engaged in ethics and civicsEthics:-Normative ethics: Theory-led approach●Ethical theory: Involves a set of principles that are meant to be applieduniversally to anyone and what they should do in general.●Apply ethical theories to ethical issues or ethical scenarios●Pick ethical theories that make the most sense and is the most reasonable ofour individual and collective lived experiences of the world●Make sure that the ethical theory you choose is the most justified and has themost explanatory power-Applied ethics: Circumstances-led approach●Looks into the who, what, when, where, why of a situation●Who: Who are the actors of a given scenario, and who are the ones receivingthe act → asking this helps us consider the context/ background of the actorsand receivers●What: Is the evidence that you’re looking atmorallyrelevant?●When: Time of action●Where: Place where action happened●Why: Look into causes and conditions of scenario●Theory-led approach and circumstances-led approach should work together-Studying ethics allows you to communicate with others about ethical issues-As students, we must pay attention to the details of everyday scenarios and becomesensitised to what might be ethical circumstances as we go about our lives
# 5
#   ### [Source Document:  resources/cc3.pdf ]
#
#      ------------------------------------
#
# =====================================================================

# %% [markdown]
# #### Step 4: Generate response from LLM based on document retrieved and query
#
# This is the last portion where will will construct the logic of the chatbot. The procedure and flow will be as follow:
# 1) Construct a LLM and system prompt
# 2) get user query.
# 3) the retrieval will return relavent chunks of documents based on query given.
# 4) construct the relavent chunks as the context along with user query.
# 5) pass the relavent chunk and user query to LLM for inferent
# 6) display the response and append into chatlog along with query.

# %%
from time import sleep
import os
import langchain
from langchain.llms import AzureOpenAI                                          ## This object is a connector/wrapper for OpenAI LLM engine
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, AIMessage, SystemMessage      ## These are the commonly used chat messages

load_dotenv(override=True)

llm = ChatOpenAI(model="gpt-3.5-turbo")

# %%
persona = "You are a teaching assistant at for the course SC1015 at NTU."
task ="your task is to answer student query about the data science and ai course."
context = "the context will be provided based on the course information and FAQ along with the user query"
condition = "If user ask any query beyond data science and ai, tell the user you are not an expert of the topic the user is asking and say sorry. If you are unsure about certain query, say sorry and advise the user to contact the instructor at instructor@ntu.edu.sg"
### any other things to add on

## Constructing initial system message
sysmsg = f"{persona} {task} {context} {condition}"
chatlog = [SystemMessage(content=sysmsg)]

# %% [markdown]
# ##### Define a function to perform the retrival and consolidation of the chunks for easy processing

# %%
def search_chunks(query):
    search_result = new_db.similarity_search(query, k=3)
    context = []
    for r in search_result:
        context.append(r.page_content)

    instruction = "try to understand the userquery and answer based on the context given below:\n"
    return SystemMessage(content=f"{instruction}'context':{context}, 'userquery':{query}")

# %%
x = search_chunks("what is the course all about?")
print(x.content)
# Out:
# try to understand the userquery and answer based on the context given below:
# 'context':['Lecture 1:Why do ethics and civics matter to everyone/ what is the purposeof studying this course?-Learn how to engage in a reasoned discussion about issues in ethics and civics(which is what we should do in a multicultural world)-Learn to critically examine the various reasons that all of us may have, given ourdifferences, to believe or act with regard to ethical issues-Different people have different ideas and conceptions as to how they should livewhether as individuals or as citizens-We belong in overlapping societies (e.g. Singapore society, Internet society, schoolsocieties)-Reflecting on the kinds of actions that either would or would not contribute to how wethink we should live, both as an individual and as a citizen, we find that this includesa wide range of concerns-Provide some direction on how we can better come up with and/ or evaluate ourreasons in all these situations and more (these situations do matter to us or others)Convincing others why we should be allowed to live our lives the waywe want:-Give reasons to explain/ justify why we think what we think-Sometimes these reasons are good or badCourse Expectations:-Identify the morally relevant features of situations, decisions and policies-Explain your moral responsibilities to actively participate in activities that strengthenyour local and global communities-Critically assess the civic structures and institutions of your communities and yourrole in them-Make well-informed arguments on some major contemporary issues-Apply ethics and civics concepts to the Singapore context-Remain open to reasons for how others might be negatively affected or how youyourself might be negatively affected → through this, we can find out why thingsmatter to us or why things matter to others\n2', 'CC000 3 Ethics and Civics in a Multicultural World  \n        \nAcademic Year  AY202 2/23 \nAcademic Units  2AUs  \nTutorial Hours  26 \n \nCOURSE AIMS  \nThis course aims to equip students with the necessary philosophical foundations to understand theories of ethics \nand subsequently apply those theories to real -life scenarios and issues. It also aims to enable students to understand \nand critically assess th e civic institutions that structure their local and global communities. To these ends, the course \nwill examine the nature of ethics, its understanding across different cultures, and how it is manifested in concepts, \nsocial structures, and governance instit utions.  \n \nTopics to be explored include human rights, democracy, freedom of speech  and inequality. The rights and duties of \ncitizenship shall be a unifying theme. Students will think through assumptions they hold on all of these matters. \nThey will be provided with the tools to understand various and even contradictory perspectives on these important \nissues. There will be a substantial amount of time devoted toward understanding Singapore’s own institutions and \nideologies, which are of course products specific to the country’s own unique historical and geo -political \ncircumstances. We expect t hat students will have a better appreciation of the country’s institutions after reading \nthe module.  \n \nINTENDED LEARNING OUTCOMES  \nBy the end of this course, you should be able to:  \n1. Identify the morally relevant features of situations, decisions, and policies;  \n2. Explain your moral responsibilities to actively participate in activities that strengthen your local and global \ncommunities;  \n3. Critically assess th e civic structures and institutions of your communities and your role in them;  \n4. Make well -informed arguments on some major contemporary issues.  \n5. Apply ethics and civics concepts to the Singapore context.  \n \nCOURSE CONTENT  \n1. Introduction – What is Ethics, Civics, Multiculturalism and how is this relevant to you?  \n2. Reasoning for ethics and civics + Logic Quiz  \n3. Human Rights Part 1: Human Trafficking  \n4. Human Rights Part 2: Disability  \n5. Reproduction Ethics  ...

# %%
query = input("Enter your message: ")
usermsg = HumanMessage(content=query)


while query != "exit":
    print(f"Human : {query}\n")
    chatlog.append(usermsg)

    context = search_chunks(query)
    templog = chatlog + [context]
    response = llm.invoke(templog)
    sleep(2)
    print(f"AI    : {response.content}\n")
    chatlog.append(response)

        
    query = input("Enter your message: ")
    usermsg = HumanMessage(content=query)
# Out:
# Human :
#
# AI    : Sorry, I am not able to provide a relevant response to the user query based on the context provided. If you have any questions related to Data Science and AI, I would be happy to help you.
#
# Human : what is this course about
#
# AI    : This course is about Ethics and Civics in a Multicultural World. It aims to provide students with the philosophical foundations to understand ethical theories and apply them to real-life scenarios and issues. Topics covered include human rights, democracy, freedom of speech, inequality, and civic institutions. The course also encourages students to critically assess civic structures and institutions, make well-informed arguments on contemporary issues, and apply ethics and civics concepts to the Singapore context. By the end of the course, students are expected to identify morally relevant features of situations, explain their moral responsibilities in local and global communities, and critically assess civic structures and institutions.
#
# Human :
#
# AI    : Sorry, I am not able to provide a relevant response to the user query based on the context provided. If you have any questions related to Data Science and AI, I would be happy to help you.

# %% [markdown]
# Also, if you recall, we specify the `chunk_size` and `chunk_overlapping` on `text_spliter` object, these are some parameter we can tune to get a better retrieval. Also the `top k` can be adjust to provide `llm` sufficient knowledge to infer user query along with creative and effective prompt design and engineering.
#
#
# Extra Readings:
# - https://learn.microsoft.com/en-us/azure/search/retrieval-augmented-generation-overview
